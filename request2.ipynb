# %%
import  requests
import time

# %%
url='http://127.0.0.1:8000/'
for i  in range(50):
    st=time.time()
    r=requests.get(url)
    print(time.time()-st)
    print(r)
# Out:
# 2.3223929405212402
# <Response [200]>
# 2.2818667888641357
# <Response [200]>
# 2.286930561065674
# <Response [200]>
# 2.4848973751068115
# <Response [200]>
# 2.319620132446289
# <Response [200]>
# 2.2606794834136963
# <Response [200]>
# 2.3025171756744385
# <Response [200]>
# 2.3013761043548584
# <Response [200]>
# 2.2809746265411377
# <Response [200]>
# 2.337733268737793
# <Response [200]>
# 2.263003349304199
# <Response [200]>
# 2.2465245723724365
# <Response [200]>
# 2.302095413208008
# <Response [200]>
# 2.288198947906494
# <Response [200]>
# 2.3495116233825684
# <Response [200]>
# 2.2510948181152344
# <Response [200]>
# 2.346606731414795
# <Response [200]>
# 2.2632980346679688
# <Response [200]>
# 2.268130302429199
# <Response [200]>
# 2.26708984375
# <Response [200]>
# 2.285879373550415
# <Response [200]>
# 2.268881320953369
# <Response [200]>
# 2.285301685333252
# <Response [200]>
# 2.3161256313323975
# <Response [200]>
# 2.3339314460754395
# <Response [200]>
# ...
